# %%
import pandas as pd

# %%
import pandas as pd

data = {'A': [10, 20, 30], 'B': [40, 50, 60]}
df = pd.DataFrame(data)
df

new_index = [0, 1, 2, 3]
df_reindexed = df.reindex(new_index)
print("Reindexed Rows:\n", df_reindexed)
# Out:
# Reindexed Rows:
#        A     B
# 0  10.0  40.0
# 1  20.0  50.0
# 2  30.0  60.0
# 3   NaN   NaN
